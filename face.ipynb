# %%
import cv2
import numpy as np
import os
import face_recognition as fr
import pyttsx3

# %%
path='Images'

# %%
os.listdir(path)
# Out:
# ['dileep.jpg',
#  'kajal.jpg',
#  'manjuwarrier.jpg',
#  'mohanlal.jpg',
#  'ramcharan.jpg']

# %%
mylist=os.listdir(path)
mylist
# Out:
# ['dileep.jpg',
#  'kajal.jpg',
#  'manjuwarrier.jpg',
#  'mohanlal.jpg',
#  'ramcharan.jpg']

# %%
imgs=[]
classnames=[]
for i in mylist:
    imgpath=os.path.join(path,i)
    img1=cv2.imread(imgpath)
    imgs.append(img1)
    classnames.append(i.split(".")[0])

# %%
print(classnames)
# Out:
# ['dileep', 'kajal', 'manjuwarrier', 'mohanlal', 'ramcharan']

# %%
# img1=imgs[0]
# cvt_img=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
# face_loc=fr.face_locations(cvt_img)
# print(face_loc)

# encoding=fr.face_encodings(cvt_img,face_loc)[0]
# encoding

# %%
def facencodings(imgs):
    encodelist=[]
    for i in imgs:
        img1=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
        face_in_frame=fr.face_locations(img1)
        #print(face_in_frame)
        face_encode=fr.face_encodings(img1,face_in_frame)[0]
        encodelist.append(face_encode)
    return encodelist

# %%
encodedlist_knownface=facencodings(imgs)

# %%
video=cv2.VideoCapture(0)
while True:
    success,img=video.read()
    img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    face_loc1=fr.face_locations(img1)
    #print(face_loc1)
    facencode1=fr.face_encodings(img1,face_loc1)
    for enc_loc,faceloc in zip(facencode1,face_loc1):
        matches=fr.compare_faces(encodedlist_knownface,enc_loc)
        #print(matches)
        face_dis=fr.face_distance(encodedlist_knownface,enc_loc)
        #print(face_dis)
        matchindex=np.argmin(face_dis)
        #print(matchindex)
        if matches[matchindex]==True:
            name=classnames[matchindex]
            print(name)
               
        else:
            name="unknown"
        engine = pyttsx3.init()
        voices = engine.getProperty('voices')
        engine.setProperty('voice', voices[1].id)
        engine.setProperty('rate', 150)  
        engine.setProperty('volume', 0.9)  
        engine.say(name)
        engine.runAndWait()
            
            
        y1,x2,y2,x1=faceloc
        cv2.rectangle(img,(x1,y1),(x2,y2),(0,255,0),3)
        cv2.putText(img,name,(x1,y1),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),3)
    cv2.imshow("webcam",img)
    if cv2.waitKey(1)&0XFF==ord('q'):
        break
video.release()
cv2.destroyAllWindows()
# Out:
# kajal
# kajal
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# manjuwarrier
# ramcharan
# ramcharan
# ramcharan
# ramcharan
